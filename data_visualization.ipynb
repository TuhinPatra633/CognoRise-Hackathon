# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./train.csv")

# %%
data
# Out:
#          Roll no test preparation   gender parental level of education  \
# 0      EXA000001              none    male                some college
# 1      EXA000002              none    male             master's degree
# 2      EXA000003              none    male             master's degree
# 3      EXA000004              none  female                some college
# 4      EXA000005              none  female                 high school
# ...          ...               ...     ...                         ...
# 31994  EXA031995              none    male            some high school
# 31995  EXA031996              none  female                 high school
# 31996  EXA031997              none    male           bachelor's degree
# 31997  EXA031998              none    male          associate's degree
# 31998  EXA031999              none    male            some high school
#
#               lunch    Section  practical score  viva score  exam score
# ...

# %%
data.columns
# Out:
# Index(['Roll no', 'test preparation ', 'gender', 'parental level of education',
#        'lunch', 'Section', 'practical score', 'viva score', 'exam score'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Roll no                        object
# test preparation               object
# gender                         object
# parental level of education    object
# lunch                          object
# Section                        object
# practical score                 int64
# viva score                      int64
# exam score                      int64
# dtype: object

# %%
for column in data.columns:
    print(f"NA values in column '{column}': {data[column].isna().sum()}")
# Out:
# NA values in column 'Roll no': 0
# NA values in column 'test preparation ': 0
# NA values in column 'gender': 0
# NA values in column 'parental level of education': 0
# NA values in column 'lunch': 0
# NA values in column 'Section': 0
# NA values in column 'practical score': 0
# NA values in column 'viva score': 0
# NA values in column 'exam score': 0

# %%
min(data["exam score"])
# Out:
# 15

# %%
min(data["viva score"])
# Out:
# 25

# %%
value_counts = data["test preparation "].value_counts()
ax = value_counts.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding count at the top of each bar
for i in ax.containers:
    ax.bar_label(i)

# Adding title and labels
plt.title('Test Preparation Distribution In Data')
plt.xlabel('Test Preparation')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Displaying the plot
plt.show()

# %%
value_counts = data["gender"].value_counts()
ax = value_counts.plot(kind='pie', colors=['blue', 'orange'], autopct='%1.1f%%', startangle=90, counterclock=False)

# Adding title
plt.title('Gender Distribution in Data')
plt.ylabel('') 

# Displaying the plot
plt.show()

# %%
value_counts = data["parental level of education"].value_counts()
plt.figure(figsize=(12, 8)) 
ax = value_counts.plot(kind='bar', color='lightgreen', edgecolor='black')

# Adding count at the top of each bar
for i in ax.containers:
    ax.bar_label(i)

# Adding title and labels

plt.title('Parental level of education In Data')
plt.xlabel('Level of Education')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Displaying the plot
plt.show()

# %%
value_counts = data["lunch"].value_counts()
plt.figure(figsize=(10, 6)) 
ax = value_counts.plot(kind='bar', color="lightblue", edgecolor='black')

# Adding count at the top of each bar
for i in ax.containers:
    ax.bar_label(i)

# Adding title and labels

plt.title('Lunch Distribution In Data')
plt.xlabel('Lunch')
plt.ylabel('Count')
plt.xticks(rotation=0)

plt.show()

# %%
value_counts = data["Section"].value_counts()
plt.figure(figsize=(12, 6)) 
ax = value_counts.plot(kind='barh', color="lightblue", edgecolor='black')

# Adding count at the top of each bar
for i in ax.containers:
    ax.bar_label(i)

# Adding title and labels

plt.title('Lunch Distribution In Data')
plt.xlabel('Lunch')
plt.ylabel('Count')
plt.xlim(0,11000)
plt.xticks(rotation=0)

plt.show()

# %%
print(f"Range Of Target Variable(Exam Score) is {min(data['exam score'])} - {max(data['exam score'])}")
# Out:
# Range Of Target Variable(Exam Score) is 15 - 100
